# %% [markdown]
# # BQ dbt mart source data extracts
# Creates the simulated source data extract files in a BigQuery storage bucket.
#
# Data extracts are based on the GCP public data set `bigquery-public-data.thelook_ecommerce` for a defined controlled
# time window - e.g. 14 days.
#
# A week is taken to be Mon - Sun to mimic the 'start-of-business' Monday scenario at the end of the defined time window.
#
# Included data sets:
#   - `bigquery-public-data.thelook_ecommerce.users`
#
# ---
# FYI - The base SQL extract statements were initally created using the dbt analysis SQL in `./bq-dbt-mart/sample_bq_dbt_mart/analyses`.
#
# The SQL statements are rendered in the `<dbt-project-dir>/target/compiled/analysis/...` directory.

# %%
# project imports
from google.cloud import bigquery
import pendulum
from structlog import get_logger

# %%
# load required notebook extensions
# %load_ext google.cloud.bigquery
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %%
# setup the BigQuery client connection
bq_client = bigquery.Client()

# setup a formatted logger
logger = get_logger()

# %%
# batch run parameters
batch_start_dt = pendulum.parse('2023-12-04').date()
batch_end_dt = batch_start_dt.add(days=13)

raw_data_bucket = 'data-pipeline-tools-raw-data'

logger.info('Batch interval', batch_start_dt=batch_start_dt.to_date_string())
logger.info('Batch interval', batch_end_dt=batch_end_dt.to_date_string())
# Out:
# 2024-01-07 18:11:00 [info     ] Batch interval                 batch_start_dt=2023-12-04
# 2024-01-07 18:11:00 [info     ] Batch interval                 batch_end_dt=2023-12-17

# %%
def full_refresh_extract_sql(src_table: str, batch_dt: pendulum.date, extract_bucket: str, extract_prefix: str) -> str:

    partition_key = f"p_year={batch_dt.year:04d}/p_month={batch_dt.month:02d}/p_day={batch_dt.day:02d}"

    sql = f"""
    export data options (
        uri='gs://{ extract_bucket }/{ extract_prefix }/full-refresh/{ src_table }/{ partition_key }/*.csv',
        format='CSV',
        overwrite=true,
        header=true
    ) AS
    SELECT *
    FROM `bigquery-public-data`.`thelook_ecommerce`.`{ src_table }`
    WHERE
        created_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY;
    """
    return sql

def full_table_extract_sql(src_table: str, batch_dt: pendulum.date, extract_bucket: str, extract_prefix: str) -> str:

    partition_key = f"p_year={batch_dt.year:04d}/p_month={batch_dt.month:02d}/p_day={batch_dt.day:02d}"

    sql = f"""
    export data options (
        uri='gs://{ extract_bucket }/{ extract_prefix }/full-refresh/{ src_table }/{ partition_key }/*.csv',
        format='CSV',
        overwrite=true,
        header=true
    ) AS
    SELECT *
    FROM `bigquery-public-data`.`thelook_ecommerce`.`{ src_table }`
    """
    return sql

# queries to extract order_items and orders records based on daily changes
#   expects the following columns to be present in the source table:
#     - created_at
#     - shipped_at
#     - delivered_at
#     - returned_at
# future timestamp values are NULL-ifed
def orders_initial_extract_sql(src_table: str, batch_dt: pendulum.date, extract_bucket: str, extract_prefix: str) -> str:
    partition_key = f"p_year={batch_dt.year:04d}/p_month={batch_dt.month:02d}/p_day={batch_dt.day:02d}"

    sql = f"""
    export data options (
        uri='gs://{ extract_bucket }/{ extract_prefix }/eod-delta/{ src_table }/{ partition_key }/*.csv',
        format='CSV',
        overwrite=true,
        header=true
    ) AS
    SELECT
        order_id
        , user_id
        , status
        , gender
        , case
            when created_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then created_at
            else null
            end as created_at
        , case
            when returned_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then returned_at
            else null
            end as returned_at
        , case
            when shipped_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then shipped_at
            else null
            end as shipped_at
        , case
            when delivered_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then delivered_at
            else null
            end as delivered_at
        , num_of_item
    FROM `bigquery-public-data`.`thelook_ecommerce`.`{ src_table }`
    WHERE
        created_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
        OR
        shipped_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
        OR
        delivered_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
        OR
        returned_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
        ;
    """

    return sql

def order_items_initial_extract_sql(src_table: str, batch_dt: pendulum.date, extract_bucket: str, extract_prefix: str) -> str:
    partition_key = f"p_year={batch_dt.year:04d}/p_month={batch_dt.month:02d}/p_day={batch_dt.day:02d}"
    
    sql = f"""
    export data options (
        uri='gs://{ extract_bucket }/{ extract_prefix }/eod-delta/{ src_table }/{ partition_key }/*.csv',
        format='CSV',
        overwrite=true,
        header=true
    ) AS
    SELECT
        id
        , order_id
        , user_id
        , product_id
        , inventory_item_id
        , status
        , case
            when created_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then created_at
            else null
            end as created_at
        , case
            when returned_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then returned_at
            else null
            end as returned_at
        , case
            when shipped_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then shipped_at
            else null
            end as shipped_at
        , case
            when delivered_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then delivered_at
            else null
            end as delivered_at
        , sale_price
    FROM `bigquery-public-data`.`thelook_ecommerce`.`{ src_table }`
    WHERE
        created_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
        OR
        shipped_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
        OR
        delivered_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
        OR
        returned_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
        ;
    """
    return sql

def inventory_items_initial_extract_sql(src_table: str, batch_dt: pendulum.date, extract_bucket: str, extract_prefix: str) -> str:
    partition_key = f"p_year={batch_dt.year:04d}/p_month={batch_dt.month:02d}/p_day={batch_dt.day:02d}"
    sql = f"""
    export data options (
        uri='gs://{ extract_bucket }/{ extract_prefix }/eod-delta/{ src_table }/{ partition_key }/*.csv',
        format='CSV',
        overwrite=true,
        header=true
    ) AS
    SELECT
        id
        , product_id
        , case
            when created_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then created_at
            else null
            end as created_at
        , case
            when sold_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then sold_at
            else null
            end as sold_at
        , cost
        , product_category
        , product_name
        , product_brand
        , product_retail_price
        , product_department
        , product_sku
        , product_distribution_center_id
    FROM `bigquery-public-data`.`thelook_ecommerce`.`{ src_table }`
    WHERE
        created_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
        OR
        sold_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
        ;
    """
    return sql

def orders_eod_delta_extract_sql(src_table: str, batch_dt: pendulum.date, extract_bucket: str, extract_prefix: str) -> str:

    partition_key = f"p_year={batch_dt.year:04d}/p_month={batch_dt.month:02d}/p_day={batch_dt.day:02d}"

    sql = f"""
    export data options (
        uri='gs://{ extract_bucket }/{ extract_prefix }/eod-delta/{ src_table }/{ partition_key }/*.csv',
        format='CSV',
        overwrite=true,
        header=true
    ) AS
    SELECT
        order_id
        , user_id
        , status
        , gender
        , case
            when created_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then created_at
            else null
            end as created_at
        , case
            when returned_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then returned_at
            else null
            end as returned_at
        , case
            when shipped_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then shipped_at
            else null
            end as shipped_at
        , case
            when delivered_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then delivered_at
            else null
            end as delivered_at
        , num_of_item
    FROM `bigquery-public-data`.`thelook_ecommerce`.`{ src_table }`
    WHERE
        (created_at >= CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
        created_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
        OR
        (shipped_at >= CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
        shipped_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
        OR
        (delivered_at >= CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
        delivered_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
        OR
        (returned_at >= CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
        returned_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
        ;
    """
    return sql

def order_items_eod_delta_extract_sql(src_table: str, batch_dt: pendulum.date, extract_bucket: str, extract_prefix: str) -> str:

    partition_key = f"p_year={batch_dt.year:04d}/p_month={batch_dt.month:02d}/p_day={batch_dt.day:02d}"

    sql = f"""
    export data options (
        uri='gs://{ extract_bucket }/{ extract_prefix }/eod-delta/{ src_table }/{ partition_key }/*.csv',
        format='CSV',
        overwrite=true,
        header=true
    ) AS
    SELECT
        id
        , order_id
        , user_id
        , product_id
        , inventory_item_id
        , status
        , case
            when created_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then created_at
            else null
            end as created_at
        , case
            when returned_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then returned_at
            else null
            end as returned_at
        , case
            when shipped_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then shipped_at
            else null
            end as shipped_at
        , case
            when delivered_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then delivered_at
            else null
            end as delivered_at
        , sale_price
    FROM `bigquery-public-data`.`thelook_ecommerce`.`{ src_table }`
    WHERE
        (created_at >= CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
        created_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
        OR
        (shipped_at >= CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
        shipped_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
        OR
        (delivered_at >= CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
        delivered_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
        OR
        (returned_at >= CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
        returned_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
        ;
    """
    return sql

# inventory_items - eod delta extract
def inventory_items_eod_delta_extract_sql(src_table: str, batch_dt: pendulum.date, extract_bucket: str, extract_prefix: str) -> str:
    partition_key = f"p_year={batch_dt.year:04d}/p_month={batch_dt.month:02d}/p_day={batch_dt.day:02d}"

    sql = f"""
    export data options (
        uri='gs://{ extract_bucket }/{ extract_prefix }/eod-delta/{ src_table }/{ partition_key }/*.csv',
        format='CSV',
        overwrite=true,
        header=true
    ) AS
    SELECT
        id
        , product_id
        , case
            when created_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then created_at
            else null
            end as created_at
        , case
            when sold_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
                then sold_at
            else null
            end as sold_at
        , cost
        , product_category
        , product_name
        , product_brand
        , product_retail_price
        , product_department
        , product_sku
        , product_distribution_center_id
    FROM `bigquery-public-data`.`thelook_ecommerce`.`{ src_table }`
    WHERE
        (created_at >= CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
        created_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
        OR
        (sold_at >= CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
        sold_at < CAST('{ batch_dt.to_date_string() } 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
        ;
    """
    return sql

# %%
# users - daily full refresh
source_table = 'users'
target_source_name = 'thelook'

for dt in pendulum.interval(batch_start_dt, batch_end_dt).range('days'):
    logger.info('batch date', dt=dt.to_date_string())

    extract_sql = full_refresh_extract_sql(source_table, dt, raw_data_bucket, target_source_name)
    logger.debug('extract SQL', sql=extract_sql)
    query_job = bq_client.query(extract_sql)
    results = query_job.result()

    logger.info('result result', status=query_job.state, errors=query_job.errors)
# Out:
# 2024-01-04 15:51:54 [info     ] batch date                     dt=2023-12-04
# 2024-01-04 15:51:54 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/users/p_year=2023/p_month=12/p_day=04/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`users`
#     WHERE
#         created_at < CAST('2023-12-04 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY;
#
# 2024-01-04 15:52:02 [info     ] result result                  errors=None status=DONE
# 2024-01-04 15:52:02 [info     ] batch date                     dt=2023-12-05
# 2024-01-04 15:52:02 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/users/p_year=2023/p_month=12/p_day=05/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`users`
#     WHERE
#         created_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY;
#
# 2024-01-04 15:52:09 [info     ] result result                  errors=None status=DONE
# 2024-01-04 15:52:09 [info     ] batch date                     dt=2023-12-06
# 2024-01-04 15:52:09 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/users/p_year=2023/p_month=12/p_day=06/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`users`
#     WHERE
#         created_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY;
#
# 2024-01-04 15:52:15 [info     ] result result                  errors=None status=DONE
# 2024-01-04 15:52:15 [info     ] batch date                     dt=2023-12-07
# 2024-01-04 15:52:15 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/users/p_year=2023/p_month=12/p_day=07/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`users`
#     WHERE
#         created_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY;
#
# 2024-01-04 15:52:21 [info     ] result result                  errors=None status=DONE
# 2024-01-04 15:52:21 [info     ] batch date                     dt=2023-12-08
# 2024-01-04 15:52:21 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/users/p_year=2023/p_month=12/p_day=08/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`users`
#     WHERE
#         created_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY;
#
# 2024-01-04 15:52:26 [info     ] result result                  errors=None status=DONE
# 2024-01-04 15:52:26 [info     ] batch date                     dt=2023-12-09
# 2024-01-04 15:52:26 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/users/p_year=2023/p_month=12/p_day=09/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`users`
#     WHERE
#         created_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY;
#
# 2024-01-04 15:52:34 [info     ] result result                  errors=None status=DONE
# 2024-01-04 15:52:34 [info     ] batch date                     dt=2023-12-10
# 2024-01-04 15:52:34 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/users/p_year=2023/p_month=12/p_day=10/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`users`
#     WHERE
#         created_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY;
#
# 2024-01-04 15:52:42 [info     ] result result                  errors=None status=DONE
# 2024-01-04 15:52:42 [info     ] batch date                     dt=2023-12-11
# 2024-01-04 15:52:42 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/users/p_year=2023/p_month=12/p_day=11/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`users`
#     WHERE
#         created_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY;
#
# 2024-01-04 15:52:47 [info     ] result result                  errors=None status=DONE
# 2024-01-04 15:52:47 [info     ] batch date                     dt=2023-12-12
# 2024-01-04 15:52:47 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/users/p_year=2023/p_month=12/p_day=12/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`users`
#     WHERE
#         created_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY;
#
# 2024-01-04 15:52:53 [info     ] result result                  errors=None status=DONE
# 2024-01-04 15:52:53 [info     ] batch date                     dt=2023-12-13
# 2024-01-04 15:52:53 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/users/p_year=2023/p_month=12/p_day=13/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`users`
#     WHERE
#         created_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY;
#
# 2024-01-04 15:53:00 [info     ] result result                  errors=None status=DONE
# 2024-01-04 15:53:00 [info     ] batch date                     dt=2023-12-14
# 2024-01-04 15:53:00 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/users/p_year=2023/p_month=12/p_day=14/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`users`
#     WHERE
#         created_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY;
#
# 2024-01-04 15:53:07 [info     ] result result                  errors=None status=DONE
# 2024-01-04 15:53:07 [info     ] batch date                     dt=2023-12-15
# 2024-01-04 15:53:07 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/users/p_year=2023/p_month=12/p_day=15/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`users`
#     WHERE
#         created_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY;
#
# 2024-01-04 15:53:14 [info     ] result result                  errors=None status=DONE
# 2024-01-04 15:53:14 [info     ] batch date                     dt=2023-12-16
# 2024-01-04 15:53:14 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/users/p_year=2023/p_month=12/p_day=16/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`users`
#     WHERE
#         created_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY;
#
# 2024-01-04 15:53:21 [info     ] result result                  errors=None status=DONE
# 2024-01-04 15:53:21 [info     ] batch date                     dt=2023-12-17
# 2024-01-04 15:53:21 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/users/p_year=2023/p_month=12/p_day=17/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`users`
#     WHERE
#         created_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY;
#
# 2024-01-04 15:53:26 [info     ] result result                  errors=None status=DONE

# %%
# distribution_centers - full table dump
# No timestamp columns available
source_table = 'distribution_centers'
targt_source_name = 'thelook'

for dt in pendulum.interval(batch_start_dt, batch_end_dt).range('days'):
    logger.info('batch date', dt=dt.to_date_string())

    extract_sql = full_table_extract_sql(source_table, dt, raw_data_bucket, target_source_name)
    logger.debug('extract SQL', sql=extract_sql)
    query_job = bq_client.query(extract_sql)
    results = query_job.result()

    logger.info('result', status=query_job.state, errors=query_job.errors)
# Out:
# 2024-01-07 18:28:57 [info     ] batch date                     dt=2023-12-04
# 2024-01-07 18:28:57 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/distribution_centers/p_year=2023/p_month=12/p_day=04/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`distribution_centers`
#
# 2024-01-07 18:29:00 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:29:00 [info     ] batch date                     dt=2023-12-05
# 2024-01-07 18:29:00 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/distribution_centers/p_year=2023/p_month=12/p_day=05/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`distribution_centers`
#
# 2024-01-07 18:29:04 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:29:04 [info     ] batch date                     dt=2023-12-06
# 2024-01-07 18:29:04 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/distribution_centers/p_year=2023/p_month=12/p_day=06/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`distribution_centers`
#
# 2024-01-07 18:29:07 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:29:07 [info     ] batch date                     dt=2023-12-07
# 2024-01-07 18:29:07 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/distribution_centers/p_year=2023/p_month=12/p_day=07/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`distribution_centers`
#
# 2024-01-07 18:29:10 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:29:10 [info     ] batch date                     dt=2023-12-08
# 2024-01-07 18:29:10 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/distribution_centers/p_year=2023/p_month=12/p_day=08/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`distribution_centers`
#
# 2024-01-07 18:29:13 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:29:13 [info     ] batch date                     dt=2023-12-09
# 2024-01-07 18:29:13 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/distribution_centers/p_year=2023/p_month=12/p_day=09/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`distribution_centers`
#
# 2024-01-07 18:29:16 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:29:16 [info     ] batch date                     dt=2023-12-10
# 2024-01-07 18:29:16 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/distribution_centers/p_year=2023/p_month=12/p_day=10/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`distribution_centers`
#
# 2024-01-07 18:29:20 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:29:20 [info     ] batch date                     dt=2023-12-11
# 2024-01-07 18:29:20 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/distribution_centers/p_year=2023/p_month=12/p_day=11/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`distribution_centers`
#
# 2024-01-07 18:29:22 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:29:22 [info     ] batch date                     dt=2023-12-12
# 2024-01-07 18:29:22 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/distribution_centers/p_year=2023/p_month=12/p_day=12/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`distribution_centers`
#
# 2024-01-07 18:29:25 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:29:25 [info     ] batch date                     dt=2023-12-13
# 2024-01-07 18:29:25 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/distribution_centers/p_year=2023/p_month=12/p_day=13/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`distribution_centers`
#
# 2024-01-07 18:29:27 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:29:27 [info     ] batch date                     dt=2023-12-14
# 2024-01-07 18:29:27 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/distribution_centers/p_year=2023/p_month=12/p_day=14/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`distribution_centers`
#
# 2024-01-07 18:29:30 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:29:30 [info     ] batch date                     dt=2023-12-15
# 2024-01-07 18:29:30 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/distribution_centers/p_year=2023/p_month=12/p_day=15/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`distribution_centers`
#
# 2024-01-07 18:29:32 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:29:32 [info     ] batch date                     dt=2023-12-16
# 2024-01-07 18:29:32 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/distribution_centers/p_year=2023/p_month=12/p_day=16/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`distribution_centers`
#
# 2024-01-07 18:29:35 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:29:35 [info     ] batch date                     dt=2023-12-17
# 2024-01-07 18:29:35 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/distribution_centers/p_year=2023/p_month=12/p_day=17/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`distribution_centers`
#
# 2024-01-07 18:29:39 [info     ] result result                  errors=None status=DONE

# %%
# products - full table dump
# No timestamp columns available
source_table = 'products'
targt_source_name = 'thelook'

for dt in pendulum.interval(batch_start_dt, batch_end_dt).range('days'):
    logger.info('batch date', dt=dt.to_date_string())

    extract_sql = full_table_extract_sql(source_table, dt, raw_data_bucket, target_source_name)
    logger.debug('extract SQL', sql=extract_sql)
    query_job = bq_client.query(extract_sql)
    results = query_job.result()

    logger.info('result', status=query_job.state, errors=query_job.errors)
# Out:
# 2024-01-07 18:38:13 [info     ] batch date                     dt=2023-12-04
# 2024-01-07 18:38:13 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/products/p_year=2023/p_month=12/p_day=04/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`products`
#
# 2024-01-07 18:38:18 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:38:18 [info     ] batch date                     dt=2023-12-05
# 2024-01-07 18:38:18 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/products/p_year=2023/p_month=12/p_day=05/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`products`
#
# 2024-01-07 18:38:23 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:38:23 [info     ] batch date                     dt=2023-12-06
# 2024-01-07 18:38:23 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/products/p_year=2023/p_month=12/p_day=06/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`products`
#
# 2024-01-07 18:38:27 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:38:27 [info     ] batch date                     dt=2023-12-07
# 2024-01-07 18:38:27 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/products/p_year=2023/p_month=12/p_day=07/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`products`
#
# 2024-01-07 18:38:32 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:38:32 [info     ] batch date                     dt=2023-12-08
# 2024-01-07 18:38:32 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/products/p_year=2023/p_month=12/p_day=08/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`products`
#
# 2024-01-07 18:38:39 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:38:39 [info     ] batch date                     dt=2023-12-09
# 2024-01-07 18:38:39 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/products/p_year=2023/p_month=12/p_day=09/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`products`
#
# 2024-01-07 18:38:44 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:38:44 [info     ] batch date                     dt=2023-12-10
# 2024-01-07 18:38:44 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/products/p_year=2023/p_month=12/p_day=10/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`products`
#
# 2024-01-07 18:38:49 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:38:49 [info     ] batch date                     dt=2023-12-11
# 2024-01-07 18:38:49 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/products/p_year=2023/p_month=12/p_day=11/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`products`
#
# 2024-01-07 18:38:55 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:38:55 [info     ] batch date                     dt=2023-12-12
# 2024-01-07 18:38:55 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/products/p_year=2023/p_month=12/p_day=12/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`products`
#
# 2024-01-07 18:39:00 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:39:00 [info     ] batch date                     dt=2023-12-13
# 2024-01-07 18:39:00 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/products/p_year=2023/p_month=12/p_day=13/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`products`
#
# 2024-01-07 18:39:04 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:39:04 [info     ] batch date                     dt=2023-12-14
# 2024-01-07 18:39:04 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/products/p_year=2023/p_month=12/p_day=14/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`products`
#
# 2024-01-07 18:39:09 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:39:09 [info     ] batch date                     dt=2023-12-15
# 2024-01-07 18:39:09 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/products/p_year=2023/p_month=12/p_day=15/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`products`
#
# 2024-01-07 18:39:14 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:39:14 [info     ] batch date                     dt=2023-12-16
# 2024-01-07 18:39:14 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/products/p_year=2023/p_month=12/p_day=16/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`products`
#
# 2024-01-07 18:39:19 [info     ] result result                  errors=None status=DONE
# 2024-01-07 18:39:19 [info     ] batch date                     dt=2023-12-17
# 2024-01-07 18:39:19 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/full-refresh/products/p_year=2023/p_month=12/p_day=17/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT *
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`products`
#
# 2024-01-07 18:39:24 [info     ] result result                  errors=None status=DONE

# %%
# orders - daily eod delta - timestamp activity during the batch day (Australia/Melbourne)
source_table = 'orders'
target_source_name = 'thelook'

orders_initial_extract_sql = orders_initial_extract_sql(source_table, batch_start_dt, raw_data_bucket, target_source_name)
query_job = bq_client.query(orders_initial_extract_sql)
results = query_job.result()
logger.info('result', status=query_job.state, errors=query_job.errors)

for dt in pendulum.interval(batch_start_dt.add(days=1), batch_end_dt).range('days'):
    logger.info('batch date', dt=dt.to_date_string())

    extract_sql = orders_eod_delta_extract_sql(source_table, dt, raw_data_bucket, target_source_name)
    logger.debug('extract SQL', sql=extract_sql)
    query_job = bq_client.query(extract_sql)
    results = query_job.result()

    logger.info('result', status=query_job.state, errors=query_job.errors)
# Out:
# 2024-01-07 20:13:17 [info     ] result                         errors=None status=DONE
# 2024-01-07 20:13:17 [info     ] batch date                     dt=2023-12-05
# 2024-01-07 20:13:17 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/orders/p_year=2023/p_month=12/p_day=05/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         order_id
#         , user_id
#         , status
#         , gender
#         , case
#             when created_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , num_of_item
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`orders`
#     WHERE
#         (created_at >= CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-07 20:13:20 [info     ] result                         errors=None status=DONE
# 2024-01-07 20:13:20 [info     ] batch date                     dt=2023-12-06
# 2024-01-07 20:13:20 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/orders/p_year=2023/p_month=12/p_day=06/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         order_id
#         , user_id
#         , status
#         , gender
#         , case
#             when created_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , num_of_item
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`orders`
#     WHERE
#         (created_at >= CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-07 20:13:23 [info     ] result                         errors=None status=DONE
# 2024-01-07 20:13:23 [info     ] batch date                     dt=2023-12-07
# 2024-01-07 20:13:23 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/orders/p_year=2023/p_month=12/p_day=07/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         order_id
#         , user_id
#         , status
#         , gender
#         , case
#             when created_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , num_of_item
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`orders`
#     WHERE
#         (created_at >= CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-07 20:13:27 [info     ] result                         errors=None status=DONE
# 2024-01-07 20:13:27 [info     ] batch date                     dt=2023-12-08
# 2024-01-07 20:13:27 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/orders/p_year=2023/p_month=12/p_day=08/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         order_id
#         , user_id
#         , status
#         , gender
#         , case
#             when created_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , num_of_item
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`orders`
#     WHERE
#         (created_at >= CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-07 20:13:30 [info     ] result                         errors=None status=DONE
# 2024-01-07 20:13:30 [info     ] batch date                     dt=2023-12-09
# 2024-01-07 20:13:30 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/orders/p_year=2023/p_month=12/p_day=09/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         order_id
#         , user_id
#         , status
#         , gender
#         , case
#             when created_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , num_of_item
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`orders`
#     WHERE
#         (created_at >= CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-07 20:13:32 [info     ] result                         errors=None status=DONE
# 2024-01-07 20:13:32 [info     ] batch date                     dt=2023-12-10
# 2024-01-07 20:13:32 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/orders/p_year=2023/p_month=12/p_day=10/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         order_id
#         , user_id
#         , status
#         , gender
#         , case
#             when created_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , num_of_item
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`orders`
#     WHERE
#         (created_at >= CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-07 20:13:36 [info     ] result                         errors=None status=DONE
# 2024-01-07 20:13:36 [info     ] batch date                     dt=2023-12-11
# 2024-01-07 20:13:36 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/orders/p_year=2023/p_month=12/p_day=11/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         order_id
#         , user_id
#         , status
#         , gender
#         , case
#             when created_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , num_of_item
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`orders`
#     WHERE
#         (created_at >= CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-07 20:13:39 [info     ] result                         errors=None status=DONE
# 2024-01-07 20:13:39 [info     ] batch date                     dt=2023-12-12
# 2024-01-07 20:13:39 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/orders/p_year=2023/p_month=12/p_day=12/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         order_id
#         , user_id
#         , status
#         , gender
#         , case
#             when created_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , num_of_item
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`orders`
#     WHERE
#         (created_at >= CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-07 20:13:42 [info     ] result                         errors=None status=DONE
# 2024-01-07 20:13:42 [info     ] batch date                     dt=2023-12-13
# 2024-01-07 20:13:42 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/orders/p_year=2023/p_month=12/p_day=13/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         order_id
#         , user_id
#         , status
#         , gender
#         , case
#             when created_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , num_of_item
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`orders`
#     WHERE
#         (created_at >= CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-07 20:13:46 [info     ] result                         errors=None status=DONE
# 2024-01-07 20:13:46 [info     ] batch date                     dt=2023-12-14
# 2024-01-07 20:13:46 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/orders/p_year=2023/p_month=12/p_day=14/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         order_id
#         , user_id
#         , status
#         , gender
#         , case
#             when created_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , num_of_item
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`orders`
#     WHERE
#         (created_at >= CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-07 20:13:49 [info     ] result                         errors=None status=DONE
# 2024-01-07 20:13:49 [info     ] batch date                     dt=2023-12-15
# 2024-01-07 20:13:49 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/orders/p_year=2023/p_month=12/p_day=15/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         order_id
#         , user_id
#         , status
#         , gender
#         , case
#             when created_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , num_of_item
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`orders`
#     WHERE
#         (created_at >= CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-07 20:13:52 [info     ] result                         errors=None status=DONE
# 2024-01-07 20:13:52 [info     ] batch date                     dt=2023-12-16
# 2024-01-07 20:13:52 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/orders/p_year=2023/p_month=12/p_day=16/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         order_id
#         , user_id
#         , status
#         , gender
#         , case
#             when created_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , num_of_item
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`orders`
#     WHERE
#         (created_at >= CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-07 20:13:55 [info     ] result                         errors=None status=DONE
# 2024-01-07 20:13:55 [info     ] batch date                     dt=2023-12-17
# 2024-01-07 20:13:55 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/orders/p_year=2023/p_month=12/p_day=17/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         order_id
#         , user_id
#         , status
#         , gender
#         , case
#             when created_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , num_of_item
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`orders`
#     WHERE
#         (created_at >= CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-07 20:13:58 [info     ] result                         errors=None status=DONE

# %%
# order_items - daily eod delta - timestamp activity during the batch day (Australia/Melbourne)
source_table = 'order_items'
target_source_name = 'thelook'

initial_extract_sql = order_items_initial_extract_sql(source_table, batch_start_dt, raw_data_bucket, target_source_name)
query_job = bq_client.query(initial_extract_sql)
results = query_job.result()
logger.info('result', status=query_job.state, errors=query_job.errors)

for dt in pendulum.interval(batch_start_dt.add(days=1), batch_end_dt).range('days'):
    logger.info('batch date', dt=dt.to_date_string())

    extract_sql = order_items_eod_delta_extract_sql(source_table, dt, raw_data_bucket, target_source_name)
    logger.debug('extract SQL', sql=extract_sql)
    query_job = bq_client.query(extract_sql)
    results = query_job.result()

    logger.info('result', status=query_job.state, errors=query_job.errors)
# Out:
# 2024-01-08 11:52:48 [info     ] result                         errors=None status=DONE
# 2024-01-08 11:52:48 [info     ] batch date                     dt=2023-12-05
# 2024-01-08 11:52:48 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/order_items/p_year=2023/p_month=12/p_day=05/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , order_id
#         , user_id
#         , product_id
#         , inventory_item_id
#         , status
#         , case
#             when created_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , sale_price
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`order_items`
#     WHERE
#         (created_at >= CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 11:52:51 [info     ] result                         errors=None status=DONE
# 2024-01-08 11:52:51 [info     ] batch date                     dt=2023-12-06
# 2024-01-08 11:52:51 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/order_items/p_year=2023/p_month=12/p_day=06/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , order_id
#         , user_id
#         , product_id
#         , inventory_item_id
#         , status
#         , case
#             when created_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , sale_price
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`order_items`
#     WHERE
#         (created_at >= CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 11:52:54 [info     ] result                         errors=None status=DONE
# 2024-01-08 11:52:54 [info     ] batch date                     dt=2023-12-07
# 2024-01-08 11:52:54 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/order_items/p_year=2023/p_month=12/p_day=07/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , order_id
#         , user_id
#         , product_id
#         , inventory_item_id
#         , status
#         , case
#             when created_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , sale_price
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`order_items`
#     WHERE
#         (created_at >= CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 11:52:57 [info     ] result                         errors=None status=DONE
# 2024-01-08 11:52:57 [info     ] batch date                     dt=2023-12-08
# 2024-01-08 11:52:57 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/order_items/p_year=2023/p_month=12/p_day=08/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , order_id
#         , user_id
#         , product_id
#         , inventory_item_id
#         , status
#         , case
#             when created_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , sale_price
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`order_items`
#     WHERE
#         (created_at >= CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 11:52:59 [info     ] result                         errors=None status=DONE
# 2024-01-08 11:52:59 [info     ] batch date                     dt=2023-12-09
# 2024-01-08 11:52:59 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/order_items/p_year=2023/p_month=12/p_day=09/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , order_id
#         , user_id
#         , product_id
#         , inventory_item_id
#         , status
#         , case
#             when created_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , sale_price
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`order_items`
#     WHERE
#         (created_at >= CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 11:53:02 [info     ] result                         errors=None status=DONE
# 2024-01-08 11:53:02 [info     ] batch date                     dt=2023-12-10
# 2024-01-08 11:53:02 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/order_items/p_year=2023/p_month=12/p_day=10/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , order_id
#         , user_id
#         , product_id
#         , inventory_item_id
#         , status
#         , case
#             when created_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , sale_price
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`order_items`
#     WHERE
#         (created_at >= CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 11:53:05 [info     ] result                         errors=None status=DONE
# 2024-01-08 11:53:05 [info     ] batch date                     dt=2023-12-11
# 2024-01-08 11:53:05 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/order_items/p_year=2023/p_month=12/p_day=11/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , order_id
#         , user_id
#         , product_id
#         , inventory_item_id
#         , status
#         , case
#             when created_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , sale_price
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`order_items`
#     WHERE
#         (created_at >= CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 11:53:08 [info     ] result                         errors=None status=DONE
# 2024-01-08 11:53:08 [info     ] batch date                     dt=2023-12-12
# 2024-01-08 11:53:08 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/order_items/p_year=2023/p_month=12/p_day=12/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , order_id
#         , user_id
#         , product_id
#         , inventory_item_id
#         , status
#         , case
#             when created_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , sale_price
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`order_items`
#     WHERE
#         (created_at >= CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 11:53:10 [info     ] result                         errors=None status=DONE
# 2024-01-08 11:53:10 [info     ] batch date                     dt=2023-12-13
# 2024-01-08 11:53:10 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/order_items/p_year=2023/p_month=12/p_day=13/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , order_id
#         , user_id
#         , product_id
#         , inventory_item_id
#         , status
#         , case
#             when created_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , sale_price
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`order_items`
#     WHERE
#         (created_at >= CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 11:53:13 [info     ] result                         errors=None status=DONE
# 2024-01-08 11:53:13 [info     ] batch date                     dt=2023-12-14
# 2024-01-08 11:53:13 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/order_items/p_year=2023/p_month=12/p_day=14/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , order_id
#         , user_id
#         , product_id
#         , inventory_item_id
#         , status
#         , case
#             when created_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , sale_price
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`order_items`
#     WHERE
#         (created_at >= CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 11:53:16 [info     ] result                         errors=None status=DONE
# 2024-01-08 11:53:16 [info     ] batch date                     dt=2023-12-15
# 2024-01-08 11:53:16 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/order_items/p_year=2023/p_month=12/p_day=15/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , order_id
#         , user_id
#         , product_id
#         , inventory_item_id
#         , status
#         , case
#             when created_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , sale_price
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`order_items`
#     WHERE
#         (created_at >= CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 11:53:19 [info     ] result                         errors=None status=DONE
# 2024-01-08 11:53:19 [info     ] batch date                     dt=2023-12-16
# 2024-01-08 11:53:19 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/order_items/p_year=2023/p_month=12/p_day=16/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , order_id
#         , user_id
#         , product_id
#         , inventory_item_id
#         , status
#         , case
#             when created_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , sale_price
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`order_items`
#     WHERE
#         (created_at >= CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 11:53:22 [info     ] result                         errors=None status=DONE
# 2024-01-08 11:53:22 [info     ] batch date                     dt=2023-12-17
# 2024-01-08 11:53:22 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/order_items/p_year=2023/p_month=12/p_day=17/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , order_id
#         , user_id
#         , product_id
#         , inventory_item_id
#         , status
#         , case
#             when created_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when returned_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then returned_at
#             else null
#             end as returned_at
#         , case
#             when shipped_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then shipped_at
#             else null
#             end as shipped_at
#         , case
#             when delivered_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then delivered_at
#             else null
#             end as delivered_at
#         , sale_price
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`order_items`
#     WHERE
#         (created_at >= CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (shipped_at >= CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         shipped_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (delivered_at >= CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         delivered_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (returned_at >= CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         returned_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 11:53:24 [info     ] result                         errors=None status=DONE

# %%
# inventory_items - daily eod delta - timestamp activity during the batch day (Australia/Melbourne)
source_table = 'inventory_items'
target_source_name = 'thelook'

initial_extract_sql = inventory_items_initial_extract_sql(source_table, batch_start_dt, raw_data_bucket, target_source_name)
logger.debug('extract SQL', sql=initial_extract_sql)
query_job = bq_client.query(initial_extract_sql)
results = query_job.result()
logger.info('result', status=query_job.state, errors=query_job.errors)

for dt in pendulum.interval(batch_start_dt.add(days=1), batch_end_dt).range('days'):
    logger.info('batch date', dt=dt.to_date_string())

    extract_sql =  inventory_items_eod_delta_extract_sql(source_table, dt, raw_data_bucket, target_source_name)
    logger.debug('extract SQL', sql=extract_sql)
    query_job = bq_client.query(extract_sql)
    results = query_job.result()

    logger.info('result', status=query_job.state, errors=query_job.errors)
# Out:
# 2024-01-08 17:49:57 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/inventory_items/p_year=2023/p_month=12/p_day=04/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , product_id
#         , case
#             when created_at < CAST('2023-12-04 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when sold_at < CAST('2023-12-04 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then sold_at
#             else null
#             end as sold_at
#         , cost
#         , product_category
#         , product_name
#         , product_brand
#         , product_retail_price
#         , product_department
#         , product_sku
#         , product_distribution_center_id
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`inventory_items`
#     WHERE
#         created_at < CAST('2023-12-04 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#         OR
#         sold_at < CAST('2023-12-04 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#         ;
#
# 2024-01-08 17:50:10 [info     ] result                         errors=None status=DONE
# 2024-01-08 17:50:10 [info     ] batch date                     dt=2023-12-05
# 2024-01-08 17:50:10 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/inventory_items/p_year=2023/p_month=12/p_day=05/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , product_id
#         , case
#             when created_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when sold_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then sold_at
#             else null
#             end as sold_at
#         , cost
#         , product_category
#         , product_name
#         , product_brand
#         , product_retail_price
#         , product_department
#         , product_sku
#         , product_distribution_center_id
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`inventory_items`
#     WHERE
#         (created_at >= CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (sold_at >= CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         sold_at < CAST('2023-12-05 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 17:50:13 [info     ] result                         errors=None status=DONE
# 2024-01-08 17:50:13 [info     ] batch date                     dt=2023-12-06
# 2024-01-08 17:50:13 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/inventory_items/p_year=2023/p_month=12/p_day=06/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , product_id
#         , case
#             when created_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when sold_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then sold_at
#             else null
#             end as sold_at
#         , cost
#         , product_category
#         , product_name
#         , product_brand
#         , product_retail_price
#         , product_department
#         , product_sku
#         , product_distribution_center_id
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`inventory_items`
#     WHERE
#         (created_at >= CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (sold_at >= CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         sold_at < CAST('2023-12-06 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 17:50:17 [info     ] result                         errors=None status=DONE
# 2024-01-08 17:50:17 [info     ] batch date                     dt=2023-12-07
# 2024-01-08 17:50:17 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/inventory_items/p_year=2023/p_month=12/p_day=07/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , product_id
#         , case
#             when created_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when sold_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then sold_at
#             else null
#             end as sold_at
#         , cost
#         , product_category
#         , product_name
#         , product_brand
#         , product_retail_price
#         , product_department
#         , product_sku
#         , product_distribution_center_id
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`inventory_items`
#     WHERE
#         (created_at >= CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (sold_at >= CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         sold_at < CAST('2023-12-07 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 17:50:21 [info     ] result                         errors=None status=DONE
# 2024-01-08 17:50:21 [info     ] batch date                     dt=2023-12-08
# 2024-01-08 17:50:21 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/inventory_items/p_year=2023/p_month=12/p_day=08/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , product_id
#         , case
#             when created_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when sold_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then sold_at
#             else null
#             end as sold_at
#         , cost
#         , product_category
#         , product_name
#         , product_brand
#         , product_retail_price
#         , product_department
#         , product_sku
#         , product_distribution_center_id
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`inventory_items`
#     WHERE
#         (created_at >= CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (sold_at >= CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         sold_at < CAST('2023-12-08 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 17:50:24 [info     ] result                         errors=None status=DONE
# 2024-01-08 17:50:24 [info     ] batch date                     dt=2023-12-09
# 2024-01-08 17:50:24 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/inventory_items/p_year=2023/p_month=12/p_day=09/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , product_id
#         , case
#             when created_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when sold_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then sold_at
#             else null
#             end as sold_at
#         , cost
#         , product_category
#         , product_name
#         , product_brand
#         , product_retail_price
#         , product_department
#         , product_sku
#         , product_distribution_center_id
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`inventory_items`
#     WHERE
#         (created_at >= CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (sold_at >= CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         sold_at < CAST('2023-12-09 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 17:50:27 [info     ] result                         errors=None status=DONE
# 2024-01-08 17:50:27 [info     ] batch date                     dt=2023-12-10
# 2024-01-08 17:50:27 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/inventory_items/p_year=2023/p_month=12/p_day=10/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , product_id
#         , case
#             when created_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when sold_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then sold_at
#             else null
#             end as sold_at
#         , cost
#         , product_category
#         , product_name
#         , product_brand
#         , product_retail_price
#         , product_department
#         , product_sku
#         , product_distribution_center_id
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`inventory_items`
#     WHERE
#         (created_at >= CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (sold_at >= CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         sold_at < CAST('2023-12-10 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 17:50:32 [info     ] result                         errors=None status=DONE
# 2024-01-08 17:50:32 [info     ] batch date                     dt=2023-12-11
# 2024-01-08 17:50:32 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/inventory_items/p_year=2023/p_month=12/p_day=11/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , product_id
#         , case
#             when created_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when sold_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then sold_at
#             else null
#             end as sold_at
#         , cost
#         , product_category
#         , product_name
#         , product_brand
#         , product_retail_price
#         , product_department
#         , product_sku
#         , product_distribution_center_id
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`inventory_items`
#     WHERE
#         (created_at >= CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (sold_at >= CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         sold_at < CAST('2023-12-11 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 17:50:36 [info     ] result                         errors=None status=DONE
# 2024-01-08 17:50:36 [info     ] batch date                     dt=2023-12-12
# 2024-01-08 17:50:36 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/inventory_items/p_year=2023/p_month=12/p_day=12/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , product_id
#         , case
#             when created_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when sold_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then sold_at
#             else null
#             end as sold_at
#         , cost
#         , product_category
#         , product_name
#         , product_brand
#         , product_retail_price
#         , product_department
#         , product_sku
#         , product_distribution_center_id
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`inventory_items`
#     WHERE
#         (created_at >= CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (sold_at >= CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         sold_at < CAST('2023-12-12 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 17:50:39 [info     ] result                         errors=None status=DONE
# 2024-01-08 17:50:39 [info     ] batch date                     dt=2023-12-13
# 2024-01-08 17:50:39 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/inventory_items/p_year=2023/p_month=12/p_day=13/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , product_id
#         , case
#             when created_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when sold_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then sold_at
#             else null
#             end as sold_at
#         , cost
#         , product_category
#         , product_name
#         , product_brand
#         , product_retail_price
#         , product_department
#         , product_sku
#         , product_distribution_center_id
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`inventory_items`
#     WHERE
#         (created_at >= CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (sold_at >= CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         sold_at < CAST('2023-12-13 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 17:50:43 [info     ] result                         errors=None status=DONE
# 2024-01-08 17:50:43 [info     ] batch date                     dt=2023-12-14
# 2024-01-08 17:50:43 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/inventory_items/p_year=2023/p_month=12/p_day=14/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , product_id
#         , case
#             when created_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when sold_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then sold_at
#             else null
#             end as sold_at
#         , cost
#         , product_category
#         , product_name
#         , product_brand
#         , product_retail_price
#         , product_department
#         , product_sku
#         , product_distribution_center_id
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`inventory_items`
#     WHERE
#         (created_at >= CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (sold_at >= CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         sold_at < CAST('2023-12-14 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 17:50:47 [info     ] result                         errors=None status=DONE
# 2024-01-08 17:50:47 [info     ] batch date                     dt=2023-12-15
# 2024-01-08 17:50:47 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/inventory_items/p_year=2023/p_month=12/p_day=15/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , product_id
#         , case
#             when created_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when sold_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then sold_at
#             else null
#             end as sold_at
#         , cost
#         , product_category
#         , product_name
#         , product_brand
#         , product_retail_price
#         , product_department
#         , product_sku
#         , product_distribution_center_id
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`inventory_items`
#     WHERE
#         (created_at >= CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (sold_at >= CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         sold_at < CAST('2023-12-15 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 17:50:50 [info     ] result                         errors=None status=DONE
# 2024-01-08 17:50:50 [info     ] batch date                     dt=2023-12-16
# 2024-01-08 17:50:50 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/inventory_items/p_year=2023/p_month=12/p_day=16/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , product_id
#         , case
#             when created_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when sold_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then sold_at
#             else null
#             end as sold_at
#         , cost
#         , product_category
#         , product_name
#         , product_brand
#         , product_retail_price
#         , product_department
#         , product_sku
#         , product_distribution_center_id
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`inventory_items`
#     WHERE
#         (created_at >= CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (sold_at >= CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         sold_at < CAST('2023-12-16 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 17:50:54 [info     ] result                         errors=None status=DONE
# 2024-01-08 17:50:54 [info     ] batch date                     dt=2023-12-17
# 2024-01-08 17:50:54 [debug    ] extract SQL                    sql=
#     export data options (
#         uri='gs://data-pipeline-tools-raw-data/thelook/eod-delta/inventory_items/p_year=2023/p_month=12/p_day=17/*.csv',
#         format='CSV',
#         overwrite=true,
#         header=true
#     ) AS
#     SELECT
#         id
#         , product_id
#         , case
#             when created_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then created_at
#             else null
#             end as created_at
#         , case
#             when sold_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY
#                 then sold_at
#             else null
#             end as sold_at
#         , cost
#         , product_category
#         , product_name
#         , product_brand
#         , product_retail_price
#         , product_department
#         , product_sku
#         , product_distribution_center_id
#     FROM `bigquery-public-data`.`thelook_ecommerce`.`inventory_items`
#     WHERE
#         (created_at >= CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         created_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         OR
#         (sold_at >= CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') AND
#         sold_at < CAST('2023-12-17 00:00:00' AS TIMESTAMP FORMAT 'YYYY-MM-DD HH24:MI:SS' AT TIME ZONE 'Australia/Melbourne') + INTERVAL '1' DAY)
#         ;
#
# 2024-01-08 17:50:58 [info     ] result                         errors=None status=DONE
